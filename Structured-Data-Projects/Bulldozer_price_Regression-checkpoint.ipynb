# %% [markdown]
# ## 🚜 Predecting the sale prive of bullzoers using machin learning
#  Notebook for study the example of predicting sales prices..of bulldozer
#
#  ## 1.Problem defination
#  >how well we predict the future sale prices using ML
# > using : https://www.kaggle.com/competitions/bluebook-for-bulldozers/data
#  ## 2.Data
#  the data is downloaded from  predicting the sale price of bulldozers sold at auctions.
#    The data for this competition is split into three parts:
#   *
# Train.csv is the training set, which contains data through the end of 2011  * .
# Valid.csv is the validation set, which contains data from January 1, 2012 - April 30, 2012 You make predictions on this set throughout the majori    ty of the competition. Your score on this set is used to create the public leaderboar  * d.
# Test.csv is the test set, which won't be released until the last week of the competition. It contains data from May 1, 2012 - November 2012. Y     our score on the test set determines your final rank for the competition.
#  ## 3.Evtionalua
#    The evaluation metric for this competition is the RMSLE (root mean squared log error) between the actual and predicted auction prices.
#    **NOTE**:eavaluation is based on RMSLE to minimise the error tion
#  ## 4.Feat
#    kaggle provided a data dictionary details all of the features of the dataset.you can view this dict. on google sheets
#    ures

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
# %matplotlib inline

# %%
df=pd.read_csv('./data/bluebook-for-bulldozers/TrainAndValid.csv',low_memory=False)
df.info()
df.describe();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412698 entries, 0 to 412697
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   object
#  9   saledate                  412698 non-null  object
#  10  fiModelDesc               412698 non-null  object
#  11  fiBaseModel               412698 non-null  object
#  12  fiSecondaryDesc           271971 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# SalesID                          0
# SalePrice                        0
# MachineID                        0
# ModelID                          0
# datasource                       0
# auctioneerID                 20136
# YearMade                         0
# MachineHoursCurrentMeter    265194
# UsageBand                   339028
# saledate                         0
# fiModelDesc                      0
# fiBaseModel                      0
# fiSecondaryDesc             140727
# fiModelSeries               354031
# fiModelDescriptor           337882
# ProductSize                 216605
# fiProductClassDesc               0
# state                            0
# ProductGroup                     0
# ProductGroupDesc                 0
# Drive_System                305611
# Enclosure                      334
# Forks                       214983
# Pad_Type                    331602
# Ride_Control                259970
# Stick                       331602
# Transmission                224691
# ...

# %%
fig,ax=plt.subplots(figsize=(10,3))
ax.scatter(df.saledate[:1000],df.SalePrice[:1000])

# %%
df=pd.read_csv('./data/bluebook-for-bulldozers/TrainAndValid.csv',
               low_memory=False,
               parse_dates=['saledate']
          )

# %%
df.saledate.head()
# Out:
# 0   2006-11-16
# 1   2004-03-26
# 2   2004-02-26
# 3   2011-05-19
# 4   2009-07-23
# Name: saledate, dtype: datetime64[ns]

# %%
fig,ax=plt.subplots(figsize=(10,3))
ax.scatter(df.saledate[:1000],df.SalePrice[:1000])

# %%
df.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246    66000.0     999089     3157         121           3.0      2004
# 1  1139248    57000.0     117657       77         121           3.0      1996
# 2  1139249    10000.0     434808     7009         121           3.0      2001
# 3  1139251    38500.0    1026470      332         121           3.0      2001
# 4  1139253    11000.0    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand   saledate  ... Undercarriage_Pad_Width  \
# 0                      68.0       Low 2006-11-16  ...                     NaN
# 1                    4640.0       Low 2004-03-26  ...                     NaN
# 2                    2838.0      High 2004-02-26  ...                     NaN
# 3                    3486.0      High 2011-05-19  ...                     NaN
# 4                     722.0    Medium 2009-07-23  ...                     NaN
#
# ...

# %%
df.head().T
# Out:
#                                                                  0  \
# SalesID                                                    1139246
# SalePrice                                                  66000.0
# MachineID                                                   999089
# ModelID                                                       3157
# datasource                                                     121
# auctioneerID                                                   3.0
# YearMade                                                      2004
# MachineHoursCurrentMeter                                      68.0
# UsageBand                                                      Low
# saledate                                       2006-11-16 00:00:00
# fiModelDesc                                                   521D
# fiBaseModel                                                    521
# fiSecondaryDesc                                                  D
# ...

# %% [markdown]
#  ## Sorting of DataFrame by saledates using sort_values()method
#
#          when working with dales,it adviced to sort the data by dates ,
#          but also make duplicate of orginal dataframe copy for taking safe side

# %%
df_temp=df.copy()
df_temp.sort_values(by=['saledate'],inplace=True)
df_temp.head().T
# Out:
#                                                                      205615  \
# SalesID                                                             1646770
# SalePrice                                                            9500.0
# MachineID                                                           1126363
# ModelID                                                                8434
# datasource                                                              132
# auctioneerID                                                           18.0
# YearMade                                                               1974
# MachineHoursCurrentMeter                                                NaN
# UsageBand                                                               NaN
# saledate                                                1989-01-17 00:00:00
# fiModelDesc                                                            TD20
# ...

# %% [markdown]
#  ##Add datetime parameters for saledate column

# %%
import datetime as dt
df_temp['saleYear']=df_temp['saledate'].dt.year
df_temp['saleMonth']=df_temp['saledate'].dt.month
df_temp['saleDay']=df_temp['saledate'].dt.day
df_temp['saleDayOfWeek']=df_temp['saledate'].dt.dayofweek
df_temp['saleDayOfYear']=df_temp['saledate'].dt.dayofyear

# %%
df_temp=df_temp.drop('saledate',axis=1);

# %%
df_temp.head()
# Out:
#         SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  \
# 205615  1646770     9500.0    1126363     8434         132          18.0
# 274835  1821514    14000.0    1194089    10150         132          99.0
# 141296  1505138    50000.0    1473654     4139         132          99.0
# 212552  1671174    16000.0    1327630     8591         132          99.0
# 62755   1329056    22000.0    1336053     4089         132          99.0
#
#         YearMade  MachineHoursCurrentMeter UsageBand fiModelDesc  ...  \
# 205615      1974                       NaN       NaN        TD20  ...
# 274835      1980                       NaN       NaN         A66  ...
# 141296      1978                       NaN       NaN         D7G  ...
# 212552      1980                       NaN       NaN         A62  ...
# 62755       1984                       NaN       NaN         D3B  ...
#
#            Backhoe_Mounting Blade_Type      Travel_Controls Differential_Type  \
# ...

# %%
df_temp.state.value_counts()
# Out:
# state
# Florida           67320
# Texas             53110
# California        29761
# Washington        16222
# Georgia           14633
# Maryland          13322
# Mississippi       13240
# Ohio              12369
# Illinois          11540
# Colorado          11529
# New Jersey        11156
# North Carolina    10636
# Tennessee         10298
# Alabama           10292
# Pennsylvania      10234
# South Carolina     9951
# Arizona            9364
# New York           8639
# Connecticut        8276
# Minnesota          7885
# Missouri           7178
# Nevada             6932
# Louisiana          6627
# Kentucky           5351
# Maine              5096
# Indiana            4124
# Arkansas           3933
# New Mexico         3631
# Utah               3046
# Unspecified        2801
# Wisconsin          2745
# New Hampshire      2738
# Virginia           2353
# Idaho              2025
# Oregon             1911
# Michigan           1831
# Wyoming            1672
# Montana            1336
# ...

# %% [markdown]
# ###  5. Modelling...
# Time to do model-driven EDA

# %%
np.random.seed(42)
# lers build machin learning model...
from sklearn.ensemble import RandomForestRegressor 
model=RandomForestRegressor(n_jobs=-1,
                           random_state=42)
model.fit(df_temp.drop('SalePrice',axis=1),df_temp['SalePrice'])

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 412698 entries, 205615 to 409203
# Data columns (total 57 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   object
#  9   fiModelDesc               412698 non-null  object
#  10  fiBaseModel               412698 non-null  object
#  11  fiSecondaryDesc           271971 non-null  object
#  12  fiModelSeries             58667 non-null   object
# ...

# %%
df_temp.isna().sum()
# Out:
# SalesID                          0
# SalePrice                        0
# MachineID                        0
# ModelID                          0
# datasource                       0
# auctioneerID                 20136
# YearMade                         0
# MachineHoursCurrentMeter    265194
# UsageBand                   339028
# fiModelDesc                      0
# fiBaseModel                      0
# fiSecondaryDesc             140727
# fiModelSeries               354031
# fiModelDescriptor           337882
# ProductSize                 216605
# fiProductClassDesc               0
# state                            0
# ProductGroup                     0
# ProductGroupDesc                 0
# Drive_System                305611
# Enclosure                      334
# Forks                       214983
# Pad_Type                    331602
# Ride_Control                259970
# Stick                       331602
# Transmission                224691
# Turbocharged                331602
# ...

# %% [markdown]
# ## Converting string data into category

# %%
pd.api.types.is_string_dtype(df_temp.UsageBand)
df_temp.UsageBand.dtype
# Out:
# dtype('O')

# %%
for labels,content in df_temp.items():
    if(pd.api.types.is_object_dtype(content)):
        print(labels)
# Out:
# UsageBand
# fiModelDesc
# fiBaseModel
# fiSecondaryDesc
# fiModelSeries
# fiModelDescriptor
# ProductSize
# fiProductClassDesc
# state
# ProductGroup
# ProductGroupDesc
# Drive_System
# Enclosure
# Forks
# Pad_Type
# Ride_Control
# Stick
# Transmission
# Turbocharged
# Blade_Extension
# Blade_Width
# Enclosure_Type
# Engine_Horsepower
# Hydraulics
# Pushblock
# Ripper
# Scarifier
# Tip_Control
# Tire_Size
# Coupler
# Coupler_System
# Grouser_Tracks
# Hydraulics_Flow
# Track_Type
# Undercarriage_Pad_Width
# Stick_Length
# Thumb
# Pattern_Changer
# Grouser_Type
# Backhoe_Mounting
# Blade_Type
# Travel_Controls
# Differential_Type
# Steering_Controls

# %%
for label,content in df_temp.items():
    if(pd.api.types.is_string_dtype(content)):
        df_temp[label]=content.astype('category').cat.as_ordered()

# %%
for label,content in df_temp.items():
    if(pd.api.types.is_object_dtype(content)):
        df_temp[label]=content.astype('category').cat.as_ordered()

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 412698 entries, 205615 to 409203
# Data columns (total 57 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   category
#  9   fiModelDesc               412698 non-null  category
#  10  fiBaseModel               412698 non-null  category
#  11  fiSecondaryDesc           271971 non-null  category
#  12  fiModelSeries             58667 non-null   category
# ...

# %%
#category is used to categorised the thing so hat we can change them tpo code and access them in numeric forms
#thanks to the pandas Categories we now have a way to access all of our data in the form of numbers

df_temp.state.cat.codes
# Out:
# 205615    43
# 274835     8
# 141296     8
# 212552     8
# 62755      8
#           ..
# 410879     4
# 412476     4
# 411927     4
# 407124     4
# 409203     4
# Length: 412698, dtype: int8

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 412698 entries, 205615 to 409203
# Data columns (total 57 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   category
#  9   fiModelDesc               412698 non-null  category
#  10  fiBaseModel               412698 non-null  category
#  11  fiSecondaryDesc           271971 non-null  category
#  12  fiModelSeries             58667 non-null   category
# ...

# %% [markdown]
# ## Save Preprocessed data

# %%
# Export curent tmp DataFram
df_temp.to_csv('data/bluebook-for-bulldozers/train_tmp.csv',
              index=False)

# %%
df_temp=pd.read_csv('data/bluebook-for-bulldozers/train_tmp.csv',low_memory=False)

# %% [markdown]
# ## Filling of missing Data
#  ## first filling of numeric values

# %%
for label,content in df_temp.items():
    if(pd.api.types.is_numeric_dtype(content)):
        print(label)
# Out:
# SalesID
# SalePrice
# MachineID
# ModelID
# datasource
# auctioneerID
# YearMade
# MachineHoursCurrentMeter
# saleYear
# saleMonth
# saleDay
# saleDayOfWeek
# saleDayOfYear

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412698 entries, 0 to 412697
# Data columns (total 57 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   object
#  9   fiModelDesc               412698 non-null  object
#  10  fiBaseModel               412698 non-null  object
#  11  fiSecondaryDesc           271971 non-null  object
#  12  fiModelSeries             58667 non-null   object
# ...

# %%
cnt=0
for label,content in df_temp.items():
    if(pd.api.types.is_numeric_dtype(content)):
            print(label)
            cnt=cnt+1


df_temp.columns.value_counts()
# Out:
# SalesID
# SalePrice
# MachineID
# ModelID
# datasource
# auctioneerID
# YearMade
# MachineHoursCurrentMeter
# saleYear
# saleMonth
# saleDay
# saleDayOfWeek
# saleDayOfYear
# SalesID                     1
# Enclosure_Type              1
# Hydraulics                  1
# Pushblock                   1
# Ripper                      1
# Scarifier                   1
# Tip_Control                 1
# Tire_Size                   1
# Coupler                     1
# Coupler_System              1
# Grouser_Tracks              1
# Hydraulics_Flow             1
# Track_Type                  1
# Undercarriage_Pad_Width     1
# Stick_Length                1
# Thumb                       1
# Pattern_Changer             1
# Grouser_Type                1
# Backhoe_Mounting            1
# Blade_Type                  1
# Travel_Controls             1
# Differential_Type           1
# Steering_Controls           1
# saleYear                    1
# saleMonth                   1
# ...

# %%
## Fill the numeric rows with the median
for label,content in df_temp.items():
    if(pd.api.types.is_numeric_dtype(content)):
        if(pd.isnull(content).sum()):
            #filling with bool values
            df_temp[label+'_is_missing']=pd.isnull(content)
            #filling of missing data with median value
            df_temp[label]=content.fillna(content.median())

# %%
df_temp.auctioneerID_is_missing.value_counts()
# Out:
# auctioneerID_is_missing
# False    392562
# True      20136
# Name: count, dtype: int64

# %%
df_temp.head().T
# Out:
#                                                                                      0  \
# SalesID                                                                        1646770
# SalePrice                                                                       9500.0
# MachineID                                                                      1126363
# ModelID                                                                           8434
# datasource                                                                         132
# auctioneerID                                                                      18.0
# YearMade                                                                          1974
# MachineHoursCurrentMeter                                                           0.0
# UsageBand                                                                          NaN
# fiModelDesc                                                                       TD20
# ...

# %%
#Turn categorical variables into numbers and fill missing ..
#...with the use of pd.categorical('series').codes which give the categorical code of respected values of category types keys/columns..
for label,content in df_temp.items():
    if not pd.api.types.is_numeric_dtype(content):
        #adding binary column to indicate whether dsample had missing value
        df_temp[label+'_is_missing']=pd.isnull(content)
        #Filling of missing values with categorical codes value
        df_temp[label]=pd.Categorical(content).codes+1

# %%
df_temp.UsageBand_is_missing.value_counts()
# Out:
# UsageBand_is_missing
# True     339028
# False     73670
# Name: count, dtype: int64

# %%
# Export curent tmp DataFram
df_temp.to_csv('data/bluebook-for-bulldozers/train_tmp.csv',
              index=False)
df_temp.head().T
# Out:
#                                     0        1        2        3        4
# SalesID                       1646770  1821514  1505138  1671174  1329056
# SalePrice                      9500.0  14000.0  50000.0  16000.0  22000.0
# MachineID                     1126363  1194089  1473654  1327630  1336053
# ModelID                          8434    10150     4139     8591     4089
# datasource                        132      132      132      132      132
# ...                               ...      ...      ...      ...      ...
# Backhoe_Mounting_is_missing     False     True    False     True    False
# Blade_Type_is_missing           False     True    False     True    False
# Travel_Controls_is_missing      False     True    False     True    False
# Differential_Type_is_missing     True    False     True    False     True
# Steering_Controls_is_missing     True    False     True    False     True
#
# [103 rows x 5 columns]

# %% [markdown]
# ## Now Its to jump on Model section ..

# %%
# %%time
#lets try Random forest classifier model
from sklearn.ensemble import RandomForestRegressor 
model=RandomForestRegressor(n_jobs=-1,
                           random_state=42)
x_train=df_temp.drop('SalePrice',axis=1)
y_train=df_temp['SalePrice']

#training of model
model.fit(x_train[:200000],y_train[:200000])
model.score(x_train[:200000],y_train[:200000])

# %%
#Splitting of data into training and validation set
#After 2011
df_val=df_temp[df_temp.saleYear==2012]
#befor 2012
df_train=df_temp[df_temp.saleYear!=2012]

# %%
#Final Spliting of data into train and validation
#training data split
x_train=df_train.drop('SalePrice',axis=1)
y_train=df_train['SalePrice']
#validation data split
x_val=df_val.drop('SalePrice',axis=1)
y_val=df_val['SalePrice']

x_train.shape,y_train.shape,x_val.shape,y_val.shape,
# Out:
# ((401125, 102), (401125,), (11573, 102), (11573,))

# %%
# %%time
#lets try Random forest classifier model
from sklearn.ensemble import RandomForestRegressor 
model=RandomForestRegressor(n_jobs=-1,
                           random_state=42)

#training of model
model.fit(x_train,y_train)
y_preds=model.predict(x_val[:10000])

# %% [markdown]
# ## Building of Differnt Evaluatiion Metrics function

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import root_mean_squared_log_error
np.random.seed(42)
evalution_method={'mean_absolute_error':mean_absolute_error,
                   'mean_squared_error':mean_squared_error,
                   'root_mean_squared_error':root_mean_squared_error,
                   'root_mean_squared_log_error':root_mean_squared_log_error
                 }
def evalution_metrics_func(y_true,y_preds,eval_methods):
    final_metrics={}
    for method,func in eval_methods.items(): 
        scores=func(y_true,y_preds)
        final_metrics[method]=scores

    return final_metrics

# %% [markdown]
# ##  Hyperprameters tuning of model to get more ACCURACY...

# %%
# %%time
#lets try Random forest classifier model
from sklearn.ensemble import RandomForestRegressor 
from sklearn.model_selection import RandomizedSearchCV


rs_grid={
 'max_depth': [3,5,10, None],
 'max_features': [0.5,1,'auto', 'sqrt'],
 'min_samples_leaf': np.arange(1,20,2),
 'min_samples_split': np.arange(2, 20, 2),
 'n_estimators': np.arange(10,100,10),
  'max_samples':[100000]}

model=RandomForestRegressor(n_jobs=-1,
                           random_state=42)
rscv_model=RandomizedSearchCV(model,
                              rs_grid,
                              n_iter=10,
                              cv=10,
                              verbose=True)
#training of model
rscv_model.fit(x_train,y_train)
y_preds=rscv_model.predict(x_val[:10000])
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# C:\Users\Chandraprakash\Desktop\projects\Bulldozer-price-prediction-project\env\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 30 fits failed out of a total of 100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Chandraprakash\Desktop\projects\Bulldozer-price-prediction-project\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
print(evalution_metrics_func(y_val[:10000],y_preds,evalution_method))
rscv_model.best_params_
# Out:
# {'mean_absolute_error': 7771.560652213591, 'mean_squared_error': 133114774.67404014, 'root_mean_squared_error': 11537.53763478326, 'root_mean_squared_log_error': 0.3118180634157546}
# {'n_estimators': 20,
#  'min_samples_split': 16,
#  'min_samples_leaf': 11,
#  'max_samples': 100000,
#  'max_features': 0.5,
#  'max_depth': 10}

# %% [markdown]
# ## hype parameters tunning with best params...
# **NOTE:These were found after 100 iterations of RandomizedSeachCV

# %%
# %%time
##Most ideal Hyperparameters
ideal_model=RandomForestRegressor(n_estimators=40,
                                 min_samples_leaf=1,
                                 min_samples_split=14,
                                 max_features=0.5,
                                 n_jobs=-1,
                                 max_samples=None,
                                 random_state=42)
#Fit the ideal model
ideal_model.fit(x_train,y_train)
# Out:
# CPU times: total: 3min 4s
# Wall time: 59.7 s
# RandomForestRegressor(max_features=0.5, min_samples_split=14, n_estimators=40,
#                       n_jobs=-1, random_state=42)

# %%
y_preds=ideal_model.predict(x_val)
print(evalution_metrics_func(y_val,y_preds,evalution_method))
# Out:
# {'mean_absolute_error': 5951.247761444453, 'mean_squared_error': 81186979.76142105, 'root_mean_squared_error': 9010.38177667412, 'root_mean_squared_log_error': 0.2452416398953833}

# %% [markdown]
# ## Features Importance...

# %%
# coef_ method is used for Logistic Regresion model
# features_importance method is used in random forest based models(regression and classification..)

feature_imp=np.array(ideal_model.feature_importances_)
feature_imp
# Out:
# array([3.39445533e-02, 1.81148281e-02, 4.09167072e-02, 1.70752171e-03,
#        3.40797459e-03, 2.08200698e-01, 2.95067052e-03, 1.10113725e-03,
#        4.16122668e-02, 4.71911805e-02, 6.23815431e-02, 4.67433955e-03,
#        1.52524442e-02, 1.52517337e-01, 4.72224713e-02, 5.96817956e-03,
#        1.29351899e-03, 2.78088439e-03, 2.37248769e-03, 6.17114453e-02,
#        8.13525488e-04, 3.61873268e-05, 9.19098115e-04, 2.23170993e-04,
#        1.28102678e-03, 2.06519636e-05, 2.01477316e-03, 6.63364759e-03,
#        2.15274492e-03, 2.50178165e-03, 4.63902393e-03, 3.85873985e-03,
#        2.76062667e-03, 1.00782454e-03, 2.47969268e-04, 6.04239818e-03,
#        7.64997072e-04, 1.57100537e-02, 2.29716203e-03, 2.58372272e-03,
#        8.07637426e-04, 9.18548690e-04, 1.35656446e-03, 5.81458569e-04,
#        4.96716928e-04, 3.79552257e-04, 5.31712788e-04, 2.71823509e-03,
#        8.34294376e-04, 3.12136841e-04, 2.14075157e-04, 7.42422919e-02,
# ...

# %%
fig,ax=plt.subplots(figsize=(20,5))
ax.bar(x_train.keys()[:10],feature_imp[:10])
ax.set(title='Different Features Importance',
      xlabel='Features',
      ylabel='Importance scores')
# Out:
# [Text(0.5, 1.0, 'Different Features Importance'),
#  Text(0.5, 0, 'Features'),
#  Text(0, 0.5, 'Importance scores')]

# %% [markdown]
# ## Make predictions of test data...

# %%
#importing test data
test_data=pd.read_csv('./data/bluebook-for-bulldozers/Test.csv',
                     parse_dates=['saledate'])

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12457 entries, 0 to 12456
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SalesID                   12457 non-null  int64
#  1   MachineID                 12457 non-null  int64
#  2   ModelID                   12457 non-null  int64
#  3   datasource                12457 non-null  int64
#  4   auctioneerID              12457 non-null  int64
#  5   YearMade                  12457 non-null  int64
#  6   MachineHoursCurrentMeter  2129 non-null   float64
#  7   UsageBand                 1834 non-null   object
#  8   saledate                  12457 non-null  datetime64[ns]
#  9   fiModelDesc               12457 non-null  object
#  10  fiBaseModel               12457 non-null  object
#  11  fiSecondaryDesc           8482 non-null   object
#  12  fiModelSeries             2006 non-null   object
# ...

# %%
 def dataframe_converter(df):
     df_temp=df.copy()
     df_temp.sort_values(by=['saledate'],inplace=True)

     #Creation of saledate related columns
     df_temp['saleYear']=df_temp['saledate'].dt.year
     df_temp['saleMonth']=df_temp['saledate'].dt.month
     df_temp['saleDay']=df_temp['saledate'].dt.day
     df_temp['saleDayOfWeek']=df_temp['saledate'].dt.dayofweek
     df_temp['saleDayOfYear']=df_temp['saledate'].dt.dayofyear

     #droping saledate col...
     df_temp=df_temp.drop('saledate',axis=1)

     temp=np.zeros((1,12457))
     df_temp['auctioneerID_is_missing']=temp.T
     
    #Conveting string dtypes into categories 
     for label,content in df_temp.items():
         if(pd.api.types.is_string_dtype(content)):
             df_temp[label]=content.astype('category').cat.as_ordered()
             
     #Conveting objects dtypes into categories
     for label,content in df_temp.items():
         if(pd.api.types.is_object_dtype(content)):
             df_temp[label]=content.astype('category').cat.as_ordered()

     ## Fill the numeric rows with the median
     for label,content in df_temp.items():
         if(pd.api.types.is_numeric_dtype(content)):
             if(pd.isnull(content).sum()):
                 #filling with bool values
                 df_temp[label+'_is_missing']=pd.isnull(content)
                 #filling of missing data with median value
                 df_temp[label]=content.fillna(content.median())
     
     #Turn categorical variables into numbers and fill missing ..
     #...with the use of pd.categorical('series').codes which give the categorical code of respected values of category types keys/columns..
     for label,content in df_temp.items():
         if not pd.api.types.is_numeric_dtype(content):
             #adding binary column to indicate whether dsample had missing value
             df_temp[label+'_is_missing']=pd.isnull(content)
             #Filling of missing values with categorical codes value
             df_temp[label]=pd.Categorical(content).codes+1
   
     return df_temp

# %%
df_test=dataframe_converter(test_data)

# %%
df_test.to_csv('./data/bluebook-for-bulldozers/convetd_Test_data.csv')
#test_preds=ideal_model.predict(df_test)

# %%
df_test_preds=ideal_model.predict(df_test)
df_test_preds
contest_output_format={'SalesID':df_test['SalesID'],
                        'SalePrice':df_test_preds}
submition_df=pd.DataFrame(contest_output_format,index=None)

submition_df.to_csv('./data/bluebook-for-bulldozers/Final_Submition_unsorted.csv')

# %%
submition_df.sort_values(by=['SalesID'],inplace=True)

# %%
submition_df.to_csv('./data/bluebook-for-bulldozers/Final_Submition.csv')

# %%
evalution_metrics_func(df_test_preds,df_test_preds ,evalution_method)
# Out:
# {'mean_absolute_error': 0.0,
#  'mean_squared_error': 0.0,
#  'root_mean_squared_error': 0.0,
#  'root_mean_squared_log_error': 0.0}
